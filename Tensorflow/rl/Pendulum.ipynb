# %%
import tensorflow as tf
import numpy as np
import gym

np.random.seed(2)
tf.set_random_seed(2)  # reproducible


class Actor(object):
    def __init__(self, sess, n_features, action_bound, lr=0.0001):
        self.sess = sess

        self.s = tf.placeholder(tf.float32, [1, n_features], "state")
        self.a = tf.placeholder(tf.float32, None, name="act")
        self.td_error = tf.placeholder(tf.float32, None, name="td_error")  # TD_error

        l1 = tf.layers.dense(
            inputs=self.s,
            units=30,  # number of hidden units
            activation=tf.nn.relu,
            kernel_initializer=tf.random_normal_initializer(0., .1),  # weights
            bias_initializer=tf.constant_initializer(0.1),  # biases
            name='l1'
        )

        mu = tf.layers.dense(
            inputs=l1,
            units=1,  # number of hidden units
            activation=tf.nn.tanh,
            kernel_initializer=tf.random_normal_initializer(0., .1),  # weights
            bias_initializer=tf.constant_initializer(0.1),  # biases
            name='mu'
        )

        sigma = tf.layers.dense(
            inputs=l1,
            units=1,  # output units
            activation=tf.nn.softplus,  # get action probabilities
            kernel_initializer=tf.random_normal_initializer(0., .1),  # weights
            bias_initializer=tf.constant_initializer(1.),  # biases
            name='sigma'
        )
        global_step = tf.Variable(0, trainable=False)
        # self.e = epsilon = tf.train.exponential_decay(2., global_step, 1000, 0.9)
        self.mu, self.sigma = tf.squeeze(mu*2), tf.squeeze(sigma+0.1)
        self.normal_dist = tf.distributions.Normal(self.mu, self.sigma)

        self.action = tf.clip_by_value(self.normal_dist.sample(1), action_bound[0], action_bound[1])

        with tf.name_scope('exp_v'):
            log_prob = self.normal_dist.log_prob(self.a)  # loss without advantage
            self.exp_v = log_prob * self.td_error  # advantage (TD_error) guided loss
            # Add cross entropy cost to encourage exploration
            self.exp_v += 0.01*self.normal_dist.entropy()

        with tf.name_scope('train'):
            self.train_op = tf.train.AdamOptimizer(lr).minimize(-self.exp_v, global_step)    # min(v) = max(-v)

    def learn(self, s, a, td):
        s = s[np.newaxis, :]
        feed_dict = {self.s: s, self.a: a, self.td_error: td}
        _, exp_v = self.sess.run([self.train_op, self.exp_v], feed_dict)
        return exp_v

    def choose_action(self, s):
        s = s[np.newaxis, :]
        return self.sess.run(self.action, {self.s: s})  # get probabilities for all actions


class Critic(object):
    def __init__(self, sess, n_features, lr=0.01):
        self.sess = sess
        with tf.name_scope('inputs'):
            self.s = tf.placeholder(tf.float32, [1, n_features], "state")
            self.v_ = tf.placeholder(tf.float32, [1, 1], name="v_next")
            self.r = tf.placeholder(tf.float32, name='r')

        with tf.variable_scope('Critic'):
            l1 = tf.layers.dense(
                inputs=self.s,
                units=30,  # number of hidden units
                activation=tf.nn.relu,
                kernel_initializer=tf.random_normal_initializer(0., .1),  # weights
                bias_initializer=tf.constant_initializer(0.1),  # biases
                name='l1'
            )

            self.v = tf.layers.dense(
                inputs=l1,
                units=1,  # output units
                activation=None,
                kernel_initializer=tf.random_normal_initializer(0., .1),  # weights
                bias_initializer=tf.constant_initializer(0.1),  # biases
                name='V'
            )

        with tf.variable_scope('squared_TD_error'):
            self.td_error = tf.reduce_mean(self.r + GAMMA * self.v_ - self.v)
            self.loss = tf.square(self.td_error)    # TD_error = (r+gamma*V_next) - V_eval
        with tf.variable_scope('train'):
            self.train_op = tf.train.AdamOptimizer(lr).minimize(self.loss)

    def learn(self, s, r, s_):
        s, s_ = s[np.newaxis, :], s_[np.newaxis, :]

        v_ = self.sess.run(self.v, {self.s: s_})
        td_error, _ = self.sess.run([self.td_error, self.train_op],
                                          {self.s: s, self.v_: v_, self.r: r})
        return td_error

# %%
OUTPUT_GRAPH = False
MAX_EPISODE = 1000
MAX_EP_STEPS = 200
DISPLAY_REWARD_THRESHOLD = -100  # renders environment if total episode reward is greater then this threshold
RENDER = False  # rendering wastes time
GAMMA = 0.9
LR_A = 0.001    # learning rate for actor
LR_C = 0.01     # learning rate for critic

env = gym.make('Pendulum-v0')
env.seed(1)  # reproducible
env = env.unwrapped

N_S = env.observation_space.shape[0]
A_BOUND = env.action_space.high

sess = tf.Session()

actor = Actor(sess, n_features=N_S, lr=LR_A, action_bound=[-A_BOUND, A_BOUND])
critic = Critic(sess, n_features=N_S, lr=LR_C)

sess.run(tf.global_variables_initializer())

if OUTPUT_GRAPH:
    tf.summary.FileWriter("logs/", sess.graph)

for i_episode in range(MAX_EPISODE):
    s = env.reset()
    t = 0
    ep_rs = []
    while True:
        # if RENDER:
        env.render()
        a = actor.choose_action(s)
        
        s_, r, done, info = env.step(a)
        r /= 10

        td_error = critic.learn(s, r, s_)  # gradient = grad[r + gamma * V(s_) - V(s)]
        actor.learn(s, a, td_error)  # true_gradient = grad[logPi(s,a) * td_error]

        s = s_
        t += 1
        ep_rs.append(r)
        if t > MAX_EP_STEPS:
            ep_rs_sum = sum(ep_rs)
            if 'running_reward' not in globals():
                running_reward = ep_rs_sum
            else:
                running_reward = running_reward * 0.9 + ep_rs_sum * 0.1
            if running_reward > DISPLAY_REWARD_THRESHOLD: RENDER = True  # rendering
            print("episode:", i_episode, "  reward:", int(running_reward))
            break
# Out:
# /Users/ianfan/anaconda3/envs/spinningup/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# WARNING: Logging before flag parsing goes to stderr.
# W0319 14:24:11.509199 4410860992 deprecation.py:323] From <ipython-input-1-413f876f4f31>:23: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0319 14:24:11.548310 4410860992 deprecation.py:323] From <ipython-input-1-413f876f4f31>:46: Normal.__init__ (from tensorflow.python.ops.distributions.normal) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# W0319 14:24:11.550029 4410860992 deprecation.py:323] From /Users/ianfan/anaconda3/envs/spinningup/lib/python3.6/site-packages/tensorflow/python/ops/distributions/normal.py:160: Distribution.__init__ (from tensorflow.python.ops.distributions.distribution) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# W0319 14:24:11.652121 4410860992 deprecation.py:506] From /Users/ianfan/anaconda3/envs/spinningup/lib/python3.6/site-packages/tensorflow/python/training/slot_creator.py:187: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# episode: 0   reward: -98
# episode: 1   reward: -104
# episode: 2   reward: -109
# episode: 3   reward: -115
# episode: 4   reward: -118
# episode: 5   reward: -124
# episode: 6   reward: -128
# episode: 7   reward: -132
# episode: 8   reward: -132
# episode: 9   reward: -135
# episode: 10   reward: -135
# episode: 11   reward: -138
# episode: 12   reward: -142
# episode: 13   reward: -142
# episode: 14   reward: -143
# episode: 15   reward: -145
# episode: 16   reward: -147
# episode: 17   reward: -146
# episode: 18   reward: -140
# episode: 19   reward: -142
# episode: 20   reward: -144
# episode: 21   reward: -145
# episode: 22   reward: -141
# episode: 23   reward: -142
# episode: 24   reward: -143
# episode: 25   reward: -145
# episode: 26   reward: -145
# episode: 27   reward: -145
# episode: 28   reward: -144
# episode: 29   reward: -143
# episode: 30   reward: -138
# episode: 31   reward: -138
# episode: 32   reward: -137
# episode: 33   reward: -137
# episode: 34   reward: -138
# episode: 35   reward: -139
# episode: 36   reward: -138
# episode: 37   reward: -137
# episode: 38   reward: -136
# episode: 39   reward: -135
# episode: 40   reward: -134
# episode: 41   reward: -136
# episode: 42   reward: -135
# episode: 43   reward: -135
# episode: 44   reward: -133
# episode: 45   reward: -135
# episode: 46   reward: -132
# episode: 47   reward: -134
# episode: 48   reward: -128
# episode: 49   reward: -129
# episode: 50   reward: -127
# episode: 51   reward: -123
# episode: 52   reward: -126
# episode: 53   reward: -128
# episode: 54   reward: -131
# episode: 55   reward: -131
# episode: 56   reward: -130
# episode: 57   reward: -129
# episode: 58   reward: -125
# episode: 59   reward: -125
# episode: 60   reward: -129
# episode: 61   reward: -131
# episode: 62   reward: -133
# episode: 63   reward: -134
# episode: 64   reward: -136
# episode: 65   reward: -138
# episode: 66   reward: -138
# episode: 67   reward: -139
# episode: 68   reward: -141
# episode: 69   reward: -142
# episode: 70   reward: -138
# episode: 71   reward: -140
# episode: 72   reward: -139
# episode: 73   reward: -139
# episode: 74   reward: -137
# episode: 75   reward: -138
# episode: 76   reward: -139
# episode: 77   reward: -136
# episode: 78   reward: -138
# episode: 79   reward: -139
# episode: 80   reward: -140
# episode: 81   reward: -138
# episode: 82   reward: -138
# episode: 83   reward: -140
# episode: 84   reward: -139
# episode: 85   reward: -139
# episode: 86   reward: -136
# episode: 87   reward: -135
# episode: 88   reward: -133
# episode: 89   reward: -133
# episode: 90   reward: -135
# episode: 91   reward: -134
# episode: 92   reward: -134
# episode: 93   reward: -131
# episode: 94   reward: -131
# episode: 95   reward: -131
# episode: 96   reward: -131
# episode: 97   reward: -131
# episode: 98   reward: -130
# episode: 99   reward: -132
# episode: 100   reward: -134
# episode: 101   reward: -133
# episode: 102   reward: -135
# episode: 103   reward: -131
# episode: 104   reward: -130
# episode: 105   reward: -129
# episode: 106   reward: -125
# episode: 107   reward: -124
# episode: 108   reward: -125
# episode: 109   reward: -124
# episode: 110   reward: -121
# episode: 111   reward: -121
# episode: 112   reward: -124
# episode: 113   reward: -122
# episode: 114   reward: -122
# episode: 115   reward: -125
# episode: 116   reward: -126
# episode: 117   reward: -129
# episode: 118   reward: -127
# episode: 119   reward: -126
# episode: 120   reward: -123
# episode: 121   reward: -123
# episode: 122   reward: -125
# episode: 123   reward: -121
# episode: 124   reward: -122
# episode: 125   reward: -124
# episode: 126   reward: -125
# episode: 127   reward: -126
# episode: 128   reward: -122
# episode: 129   reward: -118
# episode: 130   reward: -118
# episode: 131   reward: -120
# episode: 132   reward: -121
# episode: 133   reward: -121
# episode: 134   reward: -124
# episode: 135   reward: -124
# episode: 136   reward: -126
# episode: 137   reward: -125
# episode: 138   reward: -127
# episode: 139   reward: -127
# episode: 140   reward: -127
# episode: 141   reward: -128
# episode: 142   reward: -126
# episode: 143   reward: -124
# episode: 144   reward: -119
# episode: 145   reward: -122
# episode: 146   reward: -123
# episode: 147   reward: -120
# episode: 148   reward: -124
# episode: 149   reward: -121
# episode: 150   reward: -121
# episode: 151   reward: -121
# episode: 152   reward: -121
# episode: 153   reward: -121
# episode: 154   reward: -120
# episode: 155   reward: -121
# episode: 156   reward: -122
# episode: 157   reward: -122
# episode: 158   reward: -124
# episode: 159   reward: -125
# episode: 160   reward: -122
# episode: 161   reward: -121
# episode: 162   reward: -121
# episode: 163   reward: -122
# episode: 164   reward: -121
# episode: 165   reward: -118
# episode: 166   reward: -118
# episode: 167   reward: -115
# episode: 168   reward: -114
# episode: 169   reward: -113
# episode: 170   reward: -114
# episode: 171   reward: -116
# episode: 172   reward: -115
# episode: 173   reward: -116
# episode: 174   reward: -117
# episode: 175   reward: -113
# episode: 176   reward: -108
# episode: 177   reward: -105
# episode: 178   reward: -101
# episode: 179   reward: -93
# episode: 180   reward: -93
# episode: 181   reward: -95
# episode: 182   reward: -92
# episode: 183   reward: -90
# episode: 184   reward: -93
# episode: 185   reward: -86
# episode: 186   reward: -88
# episode: 187   reward: -82
# episode: 188   reward: -77
# episode: 189   reward: -83
# episode: 190   reward: -88
# episode: 191   reward: -94
# episode: 192   reward: -97
# episode: 193   reward: -90
# episode: 194   reward: -95
# episode: 195   reward: -98
# episode: 196   reward: -103
# episode: 197   reward: -95
# episode: 198   reward: -99
# episode: 199   reward: -102
# episode: 200   reward: -104
# episode: 201   reward: -99
# episode: 202   reward: -98
# episode: 203   reward: -96
# episode: 204   reward: -97
# episode: 205   reward: -94
# episode: 206   reward: -95
# episode: 207   reward: -94
# episode: 208   reward: -95
# episode: 209   reward: -95
# episode: 210   reward: -94
# episode: 211   reward: -91
# episode: 212   reward: -88
# episode: 213   reward: -84
# episode: 214   reward: -90
# episode: 215   reward: -87
# episode: 216   reward: -90
# episode: 217   reward: -86
# episode: 218   reward: -86
# episode: 219   reward: -89
# episode: 220   reward: -90
# episode: 221   reward: -92
# episode: 222   reward: -94
# episode: 223   reward: -95
# episode: 224   reward: -95
# episode: 225   reward: -96
# episode: 226   reward: -96
# episode: 227   reward: -96
# episode: 228   reward: -96
# episode: 229   reward: -94
# episode: 230   reward: -93
# episode: 231   reward: -99
# episode: 232   reward: -105
# episode: 233   reward: -99
# episode: 234   reward: -98
# episode: 235   reward: -98
# episode: 236   reward: -103
# episode: 237   reward: -100
# episode: 238   reward: -105
# episode: 239   reward: -101
# episode: 240   reward: -101
# episode: 241   reward: -103
# episode: 242   reward: -102
# episode: 243   reward: -96
# episode: 244   reward: -95
# episode: 245   reward: -92
# episode: 246   reward: -82
# episode: 247   reward: -87
# episode: 248   reward: -78
# episode: 249   reward: -85
# episode: 250   reward: -93
# episode: 251   reward: -98
# episode: 252   reward: -103
# episode: 253   reward: -109
# episode: 254   reward: -107
# episode: 255   reward: -103
# episode: 256   reward: -104
# episode: 257   reward: -106
# episode: 258   reward: -96
# episode: 259   reward: -101
# episode: 260   reward: -98
# episode: 261   reward: -88
# episode: 262   reward: -82
# episode: 263   reward: -81
# episode: 264   reward: -83
# episode: 265   reward: -74
# episode: 266   reward: -82
# episode: 267   reward: -89
# episode: 268   reward: -93
# episode: 269   reward: -90
# episode: 270   reward: -87
# episode: 271   reward: -89
# episode: 272   reward: -87
# episode: 273   reward: -84
# episode: 274   reward: -82
# episode: 275   reward: -82
# episode: 276   reward: -88
# episode: 277   reward: -94
# episode: 278   reward: -85
# episode: 279   reward: -92
# episode: 280   reward: -99
# episode: 281   reward: -102
# episode: 282   reward: -99
# episode: 283   reward: -102
# episode: 284   reward: -108
# episode: 285   reward: -106
# episode: 286   reward: -103
# episode: 287   reward: -109
# episode: 288   reward: -103
# episode: 289   reward: -98
# episode: 290   reward: -95
# episode: 291   reward: -94
# episode: 292   reward: -98
# episode: 293   reward: -104
# episode: 294   reward: -97
# episode: 295   reward: -103
# episode: 296   reward: -101
# episode: 297   reward: -101
# episode: 298   reward: -99
# episode: 299   reward: -105
# episode: 300   reward: -107
# episode: 301   reward: -106
# episode: 302   reward: -113
# episode: 303   reward: -117
# episode: 304   reward: -120
# episode: 305   reward: -114
# episode: 306   reward: -111
# episode: 307   reward: -112
# episode: 308   reward: -117
# episode: 309   reward: -114
# episode: 310   reward: -118
# episode: 311   reward: -115
# episode: 312   reward: -119
# episode: 313   reward: -123
# episode: 314   reward: -121
# episode: 315   reward: -125
# episode: 316   reward: -121
# episode: 317   reward: -117
# episode: 318   reward: -119
# episode: 319   reward: -116
# episode: 320   reward: -113
# episode: 321   reward: -109
# episode: 322   reward: -109
# episode: 323   reward: -114
# episode: 324   reward: -103
# episode: 325   reward: -100
# episode: 326   reward: -99
# episode: 327   reward: -89
# episode: 328   reward: -91
# episode: 329   reward: -90
# episode: 330   reward: -92
# episode: 331   reward: -95
# episode: 332   reward: -92
# episode: 333   reward: -89
# episode: 334   reward: -96
# episode: 335   reward: -103
# episode: 336   reward: -107
# episode: 337   reward: -96
# episode: 338   reward: -87
# episode: 339   reward: -92
# episode: 340   reward: -99
# episode: 341   reward: -99
# episode: 342   reward: -98
# episode: 343   reward: -96
# episode: 344   reward: -97
# episode: 345   reward: -105
# episode: 346   reward: -106
# episode: 347   reward: -105
# episode: 348   reward: -101
# episode: 349   reward: -107
# episode: 350   reward: -107
# episode: 351   reward: -100
# episode: 352   reward: -93
# episode: 353   reward: -100
# episode: 354   reward: -101
# episode: 355   reward: -107
# episode: 356   reward: -106
# episode: 357   reward: -106
# episode: 358   reward: -102
# episode: 359   reward: -101
# episode: 360   reward: -104
# episode: 361   reward: -95
# episode: 362   reward: -100
# episode: 363   reward: -100
# episode: 364   reward: -106
# episode: 365   reward: -104
# episode: 366   reward: -100
# episode: 367   reward: -98
# episode: 368   reward: -96
# episode: 369   reward: -94
# episode: 370   reward: -86
# episode: 371   reward: -77
# episode: 372   reward: -86
# episode: 373   reward: -89
# episode: 374   reward: -80
# episode: 375   reward: -80
# episode: 376   reward: -82
# episode: 377   reward: -82
# episode: 378   reward: -85
# episode: 379   reward: -92
# episode: 380   reward: -92
# episode: 381   reward: -100
# episode: 382   reward: -97
# episode: 383   reward: -95
# episode: 384   reward: -86
# episode: 385   reward: -83
# episode: 386   reward: -84
# episode: 387   reward: -91
# episode: 388   reward: -99
# episode: 389   reward: -105
# episode: 390   reward: -102
# episode: 391   reward: -93
# episode: 392   reward: -95
# episode: 393   reward: -102
# episode: 394   reward: -97
# episode: 395   reward: -102
# episode: 396   reward: -109
# episode: 397   reward: -110
# episode: 398   reward: -105
# episode: 399   reward: -103
# episode: 400   reward: -106
# episode: 401   reward: -110
# episode: 402   reward: -109
# episode: 403   reward: -108
# episode: 404   reward: -109
# episode: 405   reward: -115
# episode: 406   reward: -119
# episode: 407   reward: -119
# episode: 408   reward: -119
# episode: 409   reward: -120
# episode: 410   reward: -124
# episode: 411   reward: -126
# episode: 412   reward: -125
# episode: 413   reward: -125
# episode: 414   reward: -124
# episode: 415   reward: -126
# episode: 416   reward: -124
# episode: 417   reward: -126
# episode: 418   reward: -125
# episode: 419   reward: -124
# episode: 420   reward: -120
# episode: 421   reward: -116
# episode: 422   reward: -119
# episode: 423   reward: -122
# episode: 424   reward: -127
# episode: 425   reward: -132
# episode: 426   reward: -128
# episode: 427   reward: -127
# episode: 428   reward: -126
# episode: 429   reward: -121
# episode: 430   reward: -115
# episode: 431   reward: -112
# episode: 432   reward: -118
# episode: 433   reward: -117
# episode: 434   reward: -114
# episode: 435   reward: -119
# episode: 436   reward: -115
# episode: 437   reward: -109
# episode: 438   reward: -115
# episode: 439   reward: -114
# episode: 440   reward: -116
# episode: 441   reward: -115
# episode: 442   reward: -112
# episode: 443   reward: -106
# episode: 444   reward: -98
# episode: 445   reward: -106
# episode: 446   reward: -98
# episode: 447   reward: -104
# episode: 448   reward: -94
# episode: 449   reward: -96
# episode: 450   reward: -93
# episode: 451   reward: -88
# episode: 452   reward: -82
# episode: 453   reward: -86
# episode: 454   reward: -88
# episode: 455   reward: -85
# episode: 456   reward: -83
# episode: 457   reward: -82
# episode: 458   reward: -80
# episode: 459   reward: -88
# episode: 460   reward: -90
# episode: 461   reward: -90
# episode: 462   reward: -93
# episode: 463   reward: -91
# episode: 464   reward: -93
# episode: 465   reward: -94
# episode: 466   reward: -92
# episode: 467   reward: -93
# episode: 468   reward: -91
# episode: 469   reward: -91
# episode: 470   reward: -91
# episode: 471   reward: -91
# episode: 472   reward: -91
# episode: 473   reward: -93
# episode: 474   reward: -92
# episode: 475   reward: -100
# episode: 476   reward: -104
# episode: 477   reward: -111
# episode: 478   reward: -107
# episode: 479   reward: -109
# episode: 480   reward: -105
# episode: 481   reward: -105
# episode: 482   reward: -100
# episode: 483   reward: -103
# episode: 484   reward: -102
# episode: 485   reward: -102
# episode: 486   reward: -107
# episode: 487   reward: -105
# episode: 488   reward: -105
# episode: 489   reward: -103
# episode: 490   reward: -108
# episode: 491   reward: -110
# episode: 492   reward: -116
# episode: 493   reward: -120
# episode: 494   reward: -117
# episode: 495   reward: -114
# episode: 496   reward: -111
# episode: 497   reward: -109
# episode: 498   reward: -115
# episode: 499   reward: -120
# episode: 500   reward: -125
# episode: 501   reward: -121
# episode: 502   reward: -125
# episode: 503   reward: -126
# episode: 504   reward: -121
# episode: 505   reward: -119
# episode: 506   reward: -117
# episode: 507   reward: -107
# episode: 508   reward: -109
# episode: 509   reward: -110
# episode: 510   reward: -105
# episode: 511   reward: -110
# episode: 512   reward: -103
# episode: 513   reward: -108
# episode: 514   reward: -111
# episode: 515   reward: -112
# episode: 516   reward: -111
# episode: 517   reward: -117
# episode: 518   reward: -115
# episode: 519   reward: -121
# episode: 520   reward: -109
# episode: 521   reward: -113
# episode: 522   reward: -117
# episode: 523   reward: -112
# episode: 524   reward: -107
# episode: 525   reward: -113
# episode: 526   reward: -111
# episode: 527   reward: -100
# episode: 528   reward: -108
# episode: 529   reward: -114
# episode: 530   reward: -119
# episode: 531   reward: -124
# episode: 532   reward: -128
# episode: 533   reward: -122
# episode: 534   reward: -119
# episode: 535   reward: -118
# episode: 536   reward: -111
# episode: 537   reward: -107
# episode: 538   reward: -112
# episode: 539   reward: -110
# episode: 540   reward: -109
# episode: 541   reward: -114
# episode: 542   reward: -119
# episode: 543   reward: -119
# episode: 544   reward: -117
# episode: 545   reward: -115
# episode: 546   reward: -118
# episode: 547   reward: -115
# episode: 548   reward: -120
# episode: 549   reward: -120
# episode: 550   reward: -114
# episode: 551   reward: -119
# episode: 552   reward: -123
# episode: 553   reward: -119
# episode: 554   reward: -118
# episode: 555   reward: -121
# episode: 556   reward: -117
# episode: 557   reward: -123
# episode: 558   reward: -118
# episode: 559   reward: -117
# episode: 560   reward: -114
# episode: 561   reward: -109
# episode: 562   reward: -115
# episode: 563   reward: -113
# episode: 564   reward: -111
# episode: 565   reward: -110
# episode: 566   reward: -109
# episode: 567   reward: -114
# episode: 568   reward: -111
# episode: 569   reward: -116
# episode: 570   reward: -111
# episode: 571   reward: -109
# episode: 572   reward: -110
# episode: 573   reward: -114
# episode: 574   reward: -111
# episode: 575   reward: -118
# episode: 576   reward: -117
# episode: 577   reward: -122
# episode: 578   reward: -126
# episode: 579   reward: -123
# episode: 580   reward: -121
# episode: 581   reward: -125
# episode: 582   reward: -123
# episode: 583   reward: -127
# episode: 584   reward: -118
# episode: 585   reward: -117
# episode: 586   reward: -106
# episode: 587   reward: -107
# episode: 588   reward: -106
# episode: 589   reward: -106
# episode: 590   reward: -104
# episode: 591   reward: -108
# episode: 592   reward: -111
# episode: 593   reward: -115
# episode: 594   reward: -113
# episode: 595   reward: -113
# episode: 596   reward: -111
# episode: 597   reward: -115
# episode: 598   reward: -112
# episode: 599   reward: -109
# episode: 600   reward: -109
# episode: 601   reward: -105
# episode: 602   reward: -112
# episode: 603   reward: -118
# episode: 604   reward: -117
# episode: 605   reward: -120
# episode: 606   reward: -123
# episode: 607   reward: -120
# episode: 608   reward: -118
# episode: 609   reward: -108
# episode: 610   reward: -99
# episode: 611   reward: -95
# episode: 612   reward: -101
# episode: 613   reward: -103
# episode: 614   reward: -109
# episode: 615   reward: -100
# episode: 616   reward: -102
# episode: 617   reward: -108
# episode: 618   reward: -103
# episode: 619   reward: -109
# episode: 620   reward: -108
# episode: 621   reward: -113
# episode: 622   reward: -118
# episode: 623   reward: -117
# episode: 624   reward: -121
# episode: 625   reward: -119
# episode: 626   reward: -122
# episode: 627   reward: -119
# episode: 628   reward: -122
# episode: 629   reward: -121
# episode: 630   reward: -121
# episode: 631   reward: -118
# episode: 632   reward: -116
# episode: 633   reward: -115
# episode: 634   reward: -119
# episode: 635   reward: -119
# episode: 636   reward: -119
# episode: 637   reward: -122
# episode: 638   reward: -121
# episode: 639   reward: -123
# episode: 640   reward: -122
# episode: 641   reward: -121
# episode: 642   reward: -125
# episode: 643   reward: -123
# episode: 644   reward: -124
# episode: 645   reward: -121
# episode: 646   reward: -120
# episode: 647   reward: -120
# episode: 648   reward: -124
# episode: 649   reward: -124
# episode: 650   reward: -123
# episode: 651   reward: -128
# episode: 652   reward: -129
# episode: 653   reward: -128
# episode: 654   reward: -131
# episode: 655   reward: -129
# episode: 656   reward: -128
# episode: 657   reward: -128
# episode: 658   reward: -128
# episode: 659   reward: -127
# episode: 660   reward: -128
# episode: 661   reward: -127
# episode: 662   reward: -130
# episode: 663   reward: -130
# episode: 664   reward: -129
# episode: 665   reward: -129
# episode: 666   reward: -128
# episode: 667   reward: -131
# episode: 668   reward: -127
# episode: 669   reward: -127
# episode: 670   reward: -126
# episode: 671   reward: -129
# episode: 672   reward: -127
# episode: 673   reward: -130
# episode: 674   reward: -132
# episode: 675   reward: -132
# episode: 676   reward: -131
# episode: 677   reward: -132
# episode: 678   reward: -131
# episode: 679   reward: -130
# episode: 680   reward: -128
# episode: 681   reward: -127
# episode: 682   reward: -131
# episode: 683   reward: -127
# episode: 684   reward: -125
# episode: 685   reward: -125
# episode: 686   reward: -127
# episode: 687   reward: -125
# episode: 688   reward: -129
# episode: 689   reward: -129
# episode: 690   reward: -133
# episode: 691   reward: -135
# episode: 692   reward: -133
# episode: 693   reward: -135
# episode: 694   reward: -133
# episode: 695   reward: -132
# episode: 696   reward: -135
# episode: 697   reward: -133
# episode: 698   reward: -132
# episode: 699   reward: -130
# episode: 700   reward: -128
# episode: 701   reward: -126
# episode: 702   reward: -124
# episode: 703   reward: -128
# episode: 704   reward: -127
# episode: 705   reward: -132
# episode: 706   reward: -130
# episode: 707   reward: -133
# episode: 708   reward: -135
# episode: 709   reward: -137
# episode: 710   reward: -140
# episode: 711   reward: -136
# episode: 712   reward: -135
# episode: 713   reward: -133
# episode: 714   reward: -131
# episode: 715   reward: -130
# episode: 716   reward: -130
# episode: 717   reward: -131
# episode: 718   reward: -132
# episode: 719   reward: -132
# episode: 720   reward: -131
# episode: 721   reward: -130
# episode: 722   reward: -133
# episode: 723   reward: -131
# episode: 724   reward: -131
# episode: 725   reward: -131
# episode: 726   reward: -130
# episode: 727   reward: -129
# episode: 728   reward: -132
# episode: 729   reward: -134
# episode: 730   reward: -133
# episode: 731   reward: -133
# episode: 732   reward: -131
# episode: 733   reward: -130
# episode: 734   reward: -129
# episode: 735   reward: -128
# episode: 736   reward: -126
# episode: 737   reward: -125
# episode: 738   reward: -126
# episode: 739   reward: -128
# episode: 740   reward: -129
# episode: 741   reward: -131
# episode: 742   reward: -130
# episode: 743   reward: -129
# episode: 744   reward: -126
# episode: 745   reward: -126
# episode: 746   reward: -127
# episode: 747   reward: -130
# episode: 748   reward: -127
# episode: 749   reward: -127
# episode: 750   reward: -130
# episode: 751   reward: -129
# episode: 752   reward: -128
# episode: 753   reward: -127
# episode: 754   reward: -130
# episode: 755   reward: -133
# episode: 756   reward: -132
# episode: 757   reward: -130
# episode: 758   reward: -128
# episode: 759   reward: -128
# episode: 760   reward: -126
# episode: 761   reward: -126
# episode: 762   reward: -124
# episode: 763   reward: -124
# episode: 764   reward: -124
# episode: 765   reward: -123
# episode: 766   reward: -126
# episode: 767   reward: -129
# episode: 768   reward: -128
# episode: 769   reward: -129
# episode: 770   reward: -129
# episode: 771   reward: -132
# episode: 772   reward: -131
# episode: 773   reward: -129
# episode: 774   reward: -127
# episode: 775   reward: -125
# episode: 776   reward: -125
# episode: 777   reward: -124
# episode: 778   reward: -124
# episode: 779   reward: -127
# episode: 780   reward: -129
# episode: 781   reward: -130
# episode: 782   reward: -130
# episode: 783   reward: -131
# episode: 784   reward: -129
# episode: 785   reward: -126
# episode: 786   reward: -126
# episode: 787   reward: -129
# episode: 788   reward: -125
# episode: 789   reward: -129
# episode: 790   reward: -129
# episode: 791   reward: -132
# episode: 792   reward: -129
# episode: 793   reward: -127
# episode: 794   reward: -129
# episode: 795   reward: -132
# episode: 796   reward: -132
# episode: 797   reward: -131
# episode: 798   reward: -130
# episode: 799   reward: -133
# episode: 800   reward: -135
# episode: 801   reward: -135
# episode: 802   reward: -134
# episode: 803   reward: -135
# episode: 804   reward: -133
# episode: 805   reward: -132
# episode: 806   reward: -132
# episode: 807   reward: -130
# episode: 808   reward: -133
# episode: 809   reward: -134
# episode: 810   reward: -137
# episode: 811   reward: -137
# episode: 812   reward: -137
# episode: 813   reward: -134
# episode: 814   reward: -136
# episode: 815   reward: -135
# episode: 816   reward: -132
# episode: 817   reward: -131
# episode: 818   reward: -133
# episode: 819   reward: -128
# episode: 820   reward: -124
# episode: 821   reward: -128
# episode: 822   reward: -130
# episode: 823   reward: -127
# episode: 824   reward: -127
# episode: 825   reward: -129
# episode: 826   reward: -130
# episode: 827   reward: -127
# episode: 828   reward: -130
# episode: 829   reward: -125
# episode: 830   reward: -124
# episode: 831   reward: -127
# episode: 832   reward: -125
# episode: 833   reward: -128
# episode: 834   reward: -125
# episode: 835   reward: -128
# episode: 836   reward: -128
# episode: 837   reward: -131
# episode: 838   reward: -133
# episode: 839   reward: -135
# episode: 840   reward: -132
# episode: 841   reward: -128
# episode: 842   reward: -131
# episode: 843   reward: -129
# episode: 844   reward: -125
# episode: 845   reward: -129
# episode: 846   reward: -130
# episode: 847   reward: -130
# episode: 848   reward: -130
# episode: 849   reward: -133
# episode: 850   reward: -129
# episode: 851   reward: -132
# episode: 852   reward: -131
# episode: 853   reward: -132
# episode: 854   reward: -134
# episode: 855   reward: -132
# episode: 856   reward: -134
# episode: 857   reward: -131
# episode: 858   reward: -128
# episode: 859   reward: -128
# episode: 860   reward: -131
# episode: 861   reward: -128
# episode: 862   reward: -123
# episode: 863   reward: -123
# episode: 864   reward: -128
# episode: 865   reward: -130
# episode: 866   reward: -132
# episode: 867   reward: -133
# episode: 868   reward: -135
# episode: 869   reward: -130
# episode: 870   reward: -130
# episode: 871   reward: -129
# episode: 872   reward: -127
# episode: 873   reward: -124
# episode: 874   reward: -123
# episode: 875   reward: -120
# episode: 876   reward: -125
# episode: 877   reward: -126
# episode: 878   reward: -123
# episode: 879   reward: -123
# episode: 880   reward: -120
# episode: 881   reward: -121
# episode: 882   reward: -122
# episode: 883   reward: -123
# episode: 884   reward: -126
# episode: 885   reward: -126
# episode: 886   reward: -129
# episode: 887   reward: -129
# episode: 888   reward: -132
# episode: 889   reward: -129
# episode: 890   reward: -125
# episode: 891   reward: -121
# episode: 892   reward: -120
# episode: 893   reward: -120
# episode: 894   reward: -123
# episode: 895   reward: -127
# episode: 896   reward: -127
# episode: 897   reward: -124
# episode: 898   reward: -126
# episode: 899   reward: -125
# episode: 900   reward: -124
# episode: 901   reward: -124
# episode: 902   reward: -127
# episode: 903   reward: -129
# episode: 904   reward: -129
# episode: 905   reward: -128
# episode: 906   reward: -127
# episode: 907   reward: -130
# episode: 908   reward: -127
# episode: 909   reward: -124
# episode: 910   reward: -127
# episode: 911   reward: -123
# episode: 912   reward: -122
# episode: 913   reward: -121
# episode: 914   reward: -121
# episode: 915   reward: -121
# episode: 916   reward: -126
# episode: 917   reward: -123
# episode: 918   reward: -126
# episode: 919   reward: -124
# episode: 920   reward: -127
# episode: 921   reward: -125
# episode: 922   reward: -125
# episode: 923   reward: -129
# episode: 924   reward: -133
# episode: 925   reward: -132
# episode: 926   reward: -134
# episode: 927   reward: -133
# episode: 928   reward: -130
# episode: 929   reward: -129
# episode: 930   reward: -127
# episode: 931   reward: -123
# episode: 932   reward: -129
# episode: 933   reward: -128
# episode: 934   reward: -127
# episode: 935   reward: -127
# episode: 936   reward: -130
# episode: 937   reward: -134
# episode: 938   reward: -130
# episode: 939   reward: -128
# episode: 940   reward: -129
# episode: 941   reward: -128
# episode: 942   reward: -127
# episode: 943   reward: -123
# episode: 944   reward: -128
# episode: 945   reward: -131
# episode: 946   reward: -133
# episode: 947   reward: -132
# episode: 948   reward: -134
# episode: 949   reward: -131
# episode: 950   reward: -130
# episode: 951   reward: -127
# episode: 952   reward: -124
# episode: 953   reward: -128
# episode: 954   reward: -128
# episode: 955   reward: -125
# episode: 956   reward: -126
# episode: 957   reward: -128
# episode: 958   reward: -125
# episode: 959   reward: -122
# episode: 960   reward: -127
# episode: 961   reward: -125
# episode: 962   reward: -124
# episode: 963   reward: -128
# episode: 964   reward: -125
# episode: 965   reward: -125
# episode: 966   reward: -126
# episode: 967   reward: -123
# episode: 968   reward: -122
# episode: 969   reward: -121
# episode: 970   reward: -121
# episode: 971   reward: -121
# episode: 972   reward: -122
# episode: 973   reward: -122
# episode: 974   reward: -121
# episode: 975   reward: -123
# episode: 976   reward: -125
# episode: 977   reward: -123
# episode: 978   reward: -122
# episode: 979   reward: -121
# episode: 980   reward: -120
# episode: 981   reward: -117
# episode: 982   reward: -116
# episode: 983   reward: -121
# episode: 984   reward: -119
# episode: 985   reward: -118
# episode: 986   reward: -118
# episode: 987   reward: -121
# episode: 988   reward: -125
# episode: 989   reward: -123
# episode: 990   reward: -122
# episode: 991   reward: -122
# episode: 992   reward: -122
# episode: 993   reward: -120
# episode: 994   reward: -120
# episode: 995   reward: -118
# episode: 996   reward: -121
# episode: 997   reward: -119
# episode: 998   reward: -122
# episode: 999   reward: -121

# %%
total_steps = 0

for i_episode in range(10):

    observation = env.reset()
    ep_r = 0
    while True:
        env.render()

        action = RL.choose_action(observation)
        action = action * 2
        print(action)

        observation_, reward, done, info = env.step([action])
        print(observation_)

        theta_cos, theta_sin, theta_dot = observation_

        reward = - ((theta_dot)**2)

        RL.store_transition(observation, action, reward, observation_)

        if total_steps > 1000:
            RL.learn()

        ep_r += reward
        if done:
            print('episode: ', i_episode,
                  'ep_r: ', round(ep_r, 4),
                  'epsilon: ', round(RL.epsilon, 2))
            break

        observation = observation_
        total_steps += 1

RL.plot_cost()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-aea2531963a4> in <module>
#       8         env.render()
#       9
# ---> 10         action = RL.choose_action(observation)
#      11         action = action * 2
#      12         print(action)
#
# NameError: name 'RL' is not defined
